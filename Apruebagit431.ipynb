# %%
print("Hola mundo")
print("segundo hola mundo")
# Out:
# Hola mundo
# segundo hola mundo

# %%
print("Este es el hola mundo de JOHN")
# Out:
# Este es el hola mundo de JOHN

# %%
# !git remote -v
# Out:
# fatal: not a git repository (or any of the parent directories): .git
