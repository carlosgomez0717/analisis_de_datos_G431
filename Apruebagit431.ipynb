# %%
print("Hola mundo")
print("segundo hola mundo")
# Out:
# Hola mundo
# segundo hola mundo

# %%
n1= (float(input("Ingresa un número")))
n2= (float(input("Ingresa un segundo número")))
print(n1-n2)
# Out:
# Ingresa un número5
# Ingresa un segundo número2
# 3.0
